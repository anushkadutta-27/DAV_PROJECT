# %%
import pandas as pd



df = pd.read_csv(r'c:\project\netflix.csv')


print(df)
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratinglevel  ratingdescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999                                                NaN                 35
#
#      release_year  user_rating_score  user_rating_size
# 0            2004               82.0                80
# 1            2006                NaN                82
# 2            2016               98.0                80
# 3            2008               98.0                80
# 4            2014               94.0                80
# ..            ...                ...               ...
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# 999          2016               80.0                80
#
# [1000 rows x 7 columns]

# %% [markdown]
# # 1) What is the count of content by rating (e.g., TV-14, PG-13, R)? and use pie chart

# %%
rating_counts = df['rating'].value_counts()


print(rating_counts)
# Out:
# rating
# TV-14       234
# PG          170
# TV-MA       148
# G           138
# TV-Y         68
# TV-PG        59
# TV-G         52
# TV-Y7-FV     44
# TV-Y7        38
# R            19
# PG-13        15
# NR           14
# UR            1
# Name: count, dtype: int64

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.0-cp311-cp311-win_amd64.whl.metadata (106 kB)
#      ---------------------------------------- 0.0/106.6 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/106.6 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 106.6/106.6 kB 1.2 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\venv\lib\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\venv\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp311-cp311-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.3-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.2/8.1 MB 7.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/8.1 MB 8.0 MB/s eta 0:00:01
#    -------- ------------------------------- 1.7/8.1 MB 15.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.8/8.1 MB 12.7 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/8.1 MB 17.1 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/8.1 MB 16.0 MB/s eta 0:00:01
#    ------------------------- -------------- 5.1/8.1 MB 18.3 MB/s eta 0:00:01
#    ------------------------------ --------- 6.1/8.1 MB 17.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 19.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 17.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp311-cp311-win_amd64.whl (222 kB)
#    ---------------------------------------- 0.0/222.0 kB ? eta -:--:--
#    --------------------------------------- 222.0/222.0 kB 13.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------- ------------------------ 0.9/2.2 MB 28.1 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.2 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 20.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------------------------- 72.0/72.0 kB ? eta 0:00:00
# Downloading pillow-11.2.1-cp311-cp311-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------- -------------------------- 0.9/2.7 MB 28.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 21.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 18.9 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ---------------------------------------- 0.0/111.1 kB ? eta -:--:--
#    ---------------------------------------- 111.1/111.1 kB ? eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.0 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.2.1 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Content by Rating')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
# Out:
# (np.float64(-1.0999998543607892),
#  np.float64(1.0999998728931475),
#  np.float64(-1.0999970087076947),
#  np.float64(1.099999819867319))

# %% [markdown]
# # 2) What are the top 10 most common rating levels (e.g., "Parents strongly cautioned")? use horizontal bar plot

# %%
rating_counts = df['rating'].value_counts().head(10)


plt.figure(figsize=(10, 6))
rating_counts.sort_values().plot(kind='barh', color='skyblue')
plt.xlabel('Number of Titles')
plt.title('Top 10 Most Common Rating Levels')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
top_ratings = df['rating'].dropna().value_counts().head(10)


print("Top 10 Most Common Rating Levels:")
print(top_ratings)
# Out:
# Top 10 Most Common Rating Levels:
# rating
# TV-14       234
# PG          170
# TV-MA       148
# G           138
# TV-Y         68
# TV-PG        59
# TV-G         52
# TV-Y7-FV     44
# TV-Y7        38
# R            19
# Name: count, dtype: int64

# %% [markdown]
# # 3)Which years have the most content releases? Use: Bar Plot over release_year

# %%
year_counts = df['release_year'].dropna().astype(int).value_counts().sort_index()


plt.figure(figsize=(12, 6))
year_counts.plot(kind='bar', color='lightgreen')
plt.title('Number of Content Releases by Year')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
year_counts = df['release_year'].dropna().astype(int).value_counts().sort_values(ascending=False)


print("Years with the most content releases:")
print(year_counts)
# Out:
# Years with the most content releases:
# release_year
# 2016    292
# 2015    109
# 2017    100
# 2014     58
# 2013     57
# 2012     45
# 1997     28
# 1998     26
# 2008     22
# 2011     21
# 2010     20
# 2009     20
# 2006     19
# 1999     19
# 2007     18
# 2000     17
# 2003     17
# 2002     15
# 2005     14
# 1993     14
# 2001     11
# 2004      8
# 1990      7
# 1982      6
# 1994      6
# 1995      6
# 1991      5
# 1976      4
# 1986      4
# 1940      3
# 1978      2
# 1992      2
# 1989      2
# 1987      2
# 1996      1
# Name: count, dtype: int64

# %% [markdown]
# # 4)How has the user rating score trend changed over time? Use: Line Plot or Scatter Plot grouped by release_year

# %%
print(df.columns)  # Check for 'release_year' and 'user_rating_score'


df_clean = df[['release_year', 'user_rating_score']].dropna()


df_clean['release_year'] = df_clean['release_year'].astype(int)


plt.figure(figsize=(12, 6))
plt.scatter(df_clean['release_year'], df_clean['user_rating_score'], alpha=0.5, color='purple')


plt.xlabel("Release Year")
plt.ylabel("User Rating Score")
plt.title("User Rating Score Trend Over Time")
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# Index(['title', 'rating', 'ratinglevel', 'ratingdescription', 'release_year',
#        'user_rating_score', 'user_rating_size'],
#       dtype='object')

# %% [markdown]
# # 5)What is the distribution of user rating scores? use histogram

# %%
print(df.columns)  # Make sure 'user_rating_score' exists


df['user_rating_score'] = pd.to_numeric(df['user_rating_score'], errors='coerce')
df_clean = df['user_rating_score'].dropna()

plt.figure(figsize=(10, 6))
plt.hist(df_clean, bins=20, color='steelblue', edgecolor='black')

plt.xlabel("User Rating Score")
plt.ylabel("Frequency")
plt.title("Distribution of User Rating Scores")
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# Index(['title', 'rating', 'ratinglevel', 'ratingdescription', 'release_year',
#        'user_rating_score', 'user_rating_size'],
#       dtype='object')

# %% [markdown]
# # 6)What is the average user_rating_score per rating level (e.g., PG-13, R)? Use: Bar Plot with average values

# %%
df['user_rating_score'] = pd.to_numeric(df['user_rating_score'], errors='coerce')


df_clean = df[['rating', 'user_rating_score']].dropna()


avg_scores = df_clean.groupby('rating')['user_rating_score'].mean().sort_values(ascending=False)


plt.figure(figsize=(12, 6))
avg_scores.plot(kind='bar', color='mediumseagreen', edgecolor='black')

plt.xlabel("Rating Level")
plt.ylabel("Average User Rating Score")
plt.title("Average User Rating Score by Rating Level")
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(axis='y')

plt.show()

# %% [markdown]
# # 7) Which rating has the highest average rating score?  Use: Bar Plot sorted by mean score

# %%
df['user_rating_score'] = pd.to_numeric(df['user_rating_score'], errors='coerce')


df_clean = df[['rating', 'user_rating_score']].dropna()


avg_scores = df_clean.groupby('rating')['user_rating_score'].mean().sort_values(ascending=False)


plt.figure(figsize=(12, 6))
bars = avg_scores.plot(kind='bar', color='cornflowerblue', edgecolor='black')


plt.xlabel("Rating Level")
plt.ylabel("Average User Rating Score")
plt.title("Average User Rating Score by Rating Level (Sorted)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)


for bar in bars.patches:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:.2f}', 
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 8)What is the distribution of content rating scores (80, 90, 100, etc.)? Use: Pie Chart or Count Plot

# %%
df['user_rating_score'] = pd.to_numeric(df['user_rating_score'], errors='coerce')
df_clean = df['user_rating_score'].dropna()

score_counts = df_clean.value_counts().sort_index()


plt.figure(figsize=(8, 8))
plt.pie(score_counts, labels=score_counts.index.astype(int), autopct='%1.1f%%', startangle=140, colors=plt.cm.viridis_r.colors)
plt.title("Distribution of User Rating Scores (Pie Chart)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9)What is the frequency of content released by each year from 2000–2025? Use: Bar Plot

# %%
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')


df_filtered = df[(df['release_year'] >= 2000) & (df['release_year'] <= 2025)]


year_counts = df_filtered['release_year'].value_counts().sort_index()


plt.figure(figsize=(14, 6))
year_counts.plot(kind='bar', color='mediumslateblue', edgecolor='black')

plt.title('Content Releases by Year (2000-2025)')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10)What are the top 10 most frequent rating descriptions? Use: Horizontal Bar Plot

# %%
rating_counts = df['rating'].value_counts().head(10)  # Top 10


plt.figure(figsize=(10, 6))
rating_counts.plot(kind='barh', color='teal', edgecolor='black')
plt.xlabel('Frequency')
plt.ylabel('Rating Description')
plt.title('Top 10 Most Frequent Rating Descriptions')
plt.gca().invert_yaxis()  # To show the highest count on top
plt.tight_layout()
plt.show()

# %% [markdown]
# # 11)What are the common rating levels among high-scoring content (user score ≥ 90)? Use: Grouped Bar Plot

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\venv\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: pandas>=1.2 in c:\venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\venv\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ------------ --------------------------- 92.2/294.9 kB 1.3 MB/s eta 0:00:01
#    ------------------------------ --------- 225.3/294.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
df['user_rating_score'] = pd.to_numeric(df['user_rating_score'], errors='coerce')
df_clean = df.dropna(subset=['rating', 'user_rating_score'])

high_score = df_clean[df_clean['user_rating_score'] >= 90]


high_score_counts = high_score['rating'].value_counts()


all_counts = df_clean['rating'].value_counts()


plot_df = pd.DataFrame({
    'High Score (>=90)': high_score_counts,
    'All Content': all_counts
}).fillna(0)


plot_df = plot_df.sort_values(by='High Score (>=90)', ascending=False)


plt.figure(figsize=(12, 6))
plot_df.plot(kind='bar', color=['orange', 'skyblue'], edgecolor='black')

plt.title('Rating Levels Among High-Scoring Content vs All Content')
plt.xlabel('Rating Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 12)What is the average user score by each content rating (TV-14, PG-13, etc.)? Use: Bar Plot

# %%
df['user_rating_score'] = pd.to_numeric(df['user_rating_score'], errors='coerce')

df_clean = df[['rating', 'user_rating_score']].dropna()


avg_scores = df_clean.groupby('rating')['user_rating_score'].mean().sort_values(ascending=False)


plt.figure(figsize=(12, 6))
avg_scores.plot(kind='bar', color='slateblue', edgecolor='black')


plt.xlabel("Content Rating")
plt.ylabel("Average User Rating Score")
plt.title("Average User Rating Score by Content Rating")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()

plt.show()

# %% [markdown]
# # 13)Create a heatmap of average user scores by release year and rating (TV-PG, R, etc.)Use: Heatmap (release_year × rating)

# %%
df['user_rating_score'] = pd.to_numeric(df['user_rating_score'], errors='coerce')
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')


df_clean = df[['release_year', 'rating', 'user_rating_score']].dropna()


pivot_table = df_clean.pivot_table(
    index='release_year',
    columns='rating',
    values='user_rating_score',
    aggfunc='mean'
)


plt.figure(figsize=(14, 8))
sns.heatmap(pivot_table, annot=True, fmt=".1f", cmap="YlGnBu", linewidths=0.5, linecolor='gray')

plt.title("Average User Rating Score by Release Year and Content Rating", fontsize=14)
plt.xlabel("Content Rating")
plt.ylabel("Release Year")
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# # 14)Is there a correlation between ratingdescription level (e.g., "strong violence") and user rating scores?Use: Box Plot / Grouped Bar Plot

# %%
df['user_rating_score'] = pd.to_numeric(df['user_rating_score'], errors='coerce')
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')


top_rated = df[df['user_rating_score'] >= 95].dropna(subset=['release_year'])


plt.figure(figsize=(14, 6))
sns.countplot(data=top_rated, x='release_year', color='darkorange', edgecolor='black')


plt.xlabel("Release Year")
plt.ylabel("Number of Top-Rated Titles (Score ≥ 95)")
plt.title("Top-Rated Content by Year (User Score ≥ 95)")
plt.xticks(rotation=45)
plt.tight_layout()


plt.show()

# %% [markdown]
# # 15)Identify top-rated content over time – which year had the most content with user scores ≥ 95? Use: Line Plot or Count Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import kruskal
import numpy as np

data = {
    'rating_description': ['Mild']*100 + ['Moderate']*100 + ['Strong']*100,
    'user_rating': np.concatenate([
        np.random.normal(3.5, 0.8, 100),  # Mild ratings, mean ~3.5
        np.random.normal(3.2, 0.9, 100),  # Moderate ratings, mean ~3.2
        np.random.normal(3.0, 1.0, 100)   # Strong ratings, mean ~3.0
    ])
}
df = pd.DataFrame(data)


plt.figure(figsize=(10, 6))
sns.boxplot(x='rating_description', y='user_rating', data=df, order=['Mild', 'Moderate', 'Strong'])
plt.title('User Ratings by Rating Description Level')
plt.xlabel('Rating Description')
plt.ylabel('User Rating (1-5)')
plt.grid(True)


plt.savefig('rating_description_boxplot.png')


mild = df[df['rating_description'] == 'Mild']['user_rating']
moderate = df[df['rating_description'] == 'Moderate']['user_rating']
strong = df[df['rating_description'] == 'Strong']['user_rating']
stat, p_value = kruskal(mild, moderate, strong)


print(f"Kruskal-Wallis Test: Statistic={stat:.2f}, p-value={p_value:.4f}")
if p_value < 0.05:
    print("There is a statistically significant difference in user ratings across rating description levels.")
else:
    print("No statistically significant difference in user ratings across rating description levels.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 4
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 from scipy.stats import kruskal
#       5 import numpy as np
#       7 # Sample dataset
#
# ModuleNotFoundError: No module named 'scipy'

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.15.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 682.7 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.8 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 463.5 kB/s eta 0:00:00
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\venv\lib\site-packages (from scipy) (2.0.0)
# Downloading scipy-1.15.3-cp311-cp311-win_amd64.whl (41.2 MB)
#    ---------------------------------------- 0.0/41.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/41.2 MB 3.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.4/41.2 MB 4.2 MB/s eta 0:00:10
#     --------------------------------------- 1.0/41.2 MB 7.7 MB/s eta 0:00:06
#    - -------------------------------------- 1.6/41.2 MB 8.8 MB/s eta 0:00:05
#    -- ------------------------------------- 2.5/41.2 MB 11.6 MB/s eta 0:00:04
#    --- ------------------------------------ 4.1/41.2 MB 14.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.4/41.2 MB 13.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.8/41.2 MB 16.3 MB/s eta 0:00:03
#    ------ --------------------------------- 6.9/41.2 MB 16.4 MB/s eta 0:00:03
#    ------ --------------------------------- 7.1/41.2 MB 15.6 MB/s eta 0:00:03
#    -------- ------------------------------- 8.6/41.2 MB 17.1 MB/s eta 0:00:02
#    --------- ------------------------------ 10.1/41.2 MB 18.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.0/41.2 MB 20.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.1/41.2 MB 19.3 MB/s eta 0:00:02
#    ------------ --------------------------- 12.8/41.2 MB 22.6 MB/s eta 0:00:02
#    ------------ --------------------------- 13.4/41.2 MB 21.1 MB/s eta 0:00:02
#    ------------- -------------------------- 13.9/41.2 MB 19.8 MB/s eta 0:00:02
#    -------------- ------------------------- 15.2/41.2 MB 21.1 MB/s eta 0:00:02
#    --------------- ------------------------ 16.4/41.2 MB 21.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 17.4/41.2 MB 22.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 18.1/41.2 MB 19.8 MB/s eta 0:00:02
#    ------------------- -------------------- 20.1/41.2 MB 21.9 MB/s eta 0:00:01
#    -------------------- ------------------- 21.1/41.2 MB 23.4 MB/s eta 0:00:01
#    --------------------- ------------------ 22.5/41.2 MB 24.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 23.7/41.2 MB 27.3 MB/s eta 0:00:01
#    ------------------------ --------------- 24.8/41.2 MB 26.2 MB/s eta 0:00:01
#    ------------------------- -------------- 25.9/41.2 MB 27.3 MB/s eta 0:00:01
#    -------------------------- ------------- 26.9/41.2 MB 26.2 MB/s eta 0:00:01
#    --------------------------- ------------ 28.2/41.2 MB 27.3 MB/s eta 0:00:01
#    --------------------------- ------------ 28.8/41.2 MB 26.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 29.5/41.2 MB 25.1 MB/s eta 0:00:01
#    ------------------------------ --------- 31.6/41.2 MB 25.2 MB/s eta 0:00:01
#    ------------------------------- -------- 32.6/41.2 MB 24.2 MB/s eta 0:00:01
#    -------------------------------- ------- 33.2/41.2 MB 24.2 MB/s eta 0:00:01
#    --------------------------------- ------ 34.4/41.2 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 35.7/41.2 MB 24.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.9/41.2 MB 24.2 MB/s eta 0:00:01
#    ------------------------------------ --- 38.0/41.2 MB 24.2 MB/s eta 0:00:01
#    ------------------------------------- -- 39.0/41.2 MB 25.1 MB/s eta 0:00:01
#    -------------------------------------- - 40.2/41.2 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------- 41.2/41.2 MB 16.8 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.15.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import kruskal
import numpy as np


data = {
    'rating_description': ['Mild']*100 + ['Moderate']*100 + ['Strong']*100,
    'user_rating': np.concatenate([
        np.random.normal(3.5, 0.8, 100),  # Mild ratings, mean ~3.5
        np.random.normal(3.2, 0.9, 100),  # Moderate ratings, mean ~3.2
        np.random.normal(3.0, 1.0, 100)   # Strong ratings, mean ~3.0
    ])
}
df = pd.DataFrame(data)


plt.figure(figsize=(10, 6))
sns.boxplot(x='rating_description', y='user_rating', data=df, order=['Mild', 'Moderate', 'Strong'])
plt.title('User Ratings by Rating Description Level')
plt.xlabel('Rating Description')
plt.ylabel('User Rating (1-5)')
plt.grid(True)


plt.savefig('rating_description_boxplot.png')


mild = df[df['rating_description'] == 'Mild']['user_rating']
moderate = df[df['rating_description'] == 'Moderate']['user_rating']
strong = df[df['rating_description'] == 'Strong']['user_rating']
stat, p_value = kruskal(mild, moderate, strong)


print(f"Kruskal-Wallis Test: Statistic={stat:.2f}, p-value={p_value:.4f}")
if p_value < 0.05:
    print("There is a statistically significant difference in user ratings across rating description levels.")
else:
    print("No statistically significant difference in user ratings across rating description levels.")
# Out:
# Kruskal-Wallis Test: Statistic=37.30, p-value=0.0000
# There is a statistically significant difference in user ratings across rating description levels.
